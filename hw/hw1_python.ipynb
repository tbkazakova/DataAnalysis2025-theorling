# %% [markdown]
# # 1. M-reduplication (1 point)
#
# The user enters a word in any case, the programm gives him a lowercase word with m-reduplication
# ```
# - cupboards
# - cupboards-mupboards
#
# - cat
# - cat-mat
#
# - HuHrY
# - huhry-muhry
# ```

# %% [markdown]
# # 2. Multiplication table (1 point)
#
# Print the multiplication table from 2 to 9. Your code should be no more than 4 lines of code.
#
# ```
# 2 * 2 = 4
# 2 * 3 = 6
# ...
# 2 * 9 = 18
# ```
# ```
# 3 * 2 = 6
# 3 * 3 = 9
# ...
# 3 * 9 = 27
# ```
#
# Up to 9 * 9 = 81
#
# Tip: use `range()`

# %% [markdown]
# # 3. Cacti (2 points)
#
# This is a collection of cacti. A dictionary with the genus, height (in cm), and color of the cactus is available by name.
#
# Cacti that haven't yet bloomed have flower_color = "UNK" (unknown)
#
# Your code should solve the following for this dictionary and for a dictionary of a similar structure (one cell per one task):
#
# 3.1 What is the tallest cactus?
#
# 3.2 How many cacti are taller than 20 cm?
#
# 3.3 What are the names of cleistocacti?
#
# 3.4 Add `Tosha` (notocactus, 8 cm, yellow flower) to the collection.
#
# 3.5 `Star` has grown half a centimeter. Update its height.

# %%
cacti = {'Athena': {'genus': 'Echinopsis', 'height': 12, 'flower_color': 'light pink'},
        'Appolinaria': {'genus': 'Prickly Pear', 'height': 20, 'flower_color': 'UNK'},
        'Opuka': {'genus': 'Prickly Pear', 'height': 14, 'flower_color': 'UNK'},
        'Star': {'genus': 'Astrophytum', 'height': 8, 'flower_color': 'yellow'},
        'Hattifattener A': {'genus': 'Cleistocactus', 'height': 43, 'flower_color': 'UNK'},
        'Hattifattener B': {'genus': 'Cleistocactus', 'height': 34, 'flower_color': 'UNK'},
        'Little': {'genus': 'Mammillaria', 'height': 7, 'flower_color': 'pink'},
        'Cute': {'genus': 'Mammillaria', 'height': 11, 'flower_color': 'crimson'}
        }

# %% [markdown]
# # 4. Define the correct function for titles (1 point)
#
# For example, "the cat in the hat".title() ==> "The Cat In The Hat", but we want "The Cat in the Hat"

# %%
def proper_title_case(s):
    nocaps = ["the", "in", "on", "a", "an"] # This needs to be extended.
    # Your code
    return # here goes what you want the function to return

print(proper_title_case('An ant on a table')) # to test your function
print(proper_title_case('The Cat In the Hat')) # to test your function

# %% [markdown]
# # 5. Standard deviation (2 points)
# Complete the function sd for calculating the standard deviation of a list of numeric values. Your function should take a list and return a float.
#
# For details on calculating the standard deviation, see http://en.wikipedia.org/wiki/Standard_deviation
#
# I suggest using float(len(vals)-1) for the denominator, but float(len(vals)) is fine. To get the square root of a float x, use math.sqrt(x)

# %%
import math

def sd(vals):
    """Return the standard deviation of the values in vals,
    presupposed to be numeric (float, int)."""
    # Your code
    return # here goes what you want the function to return

print(sd([0, 1, 2])) # to test your function

# %% [markdown]
# # 6. Can I get your number? (3 points)
#
# Write a function to standardise phone numbers.
#
# The function should accept a string containing a phone number. It can be used for any of the following numbers:
# ```
# "8 (910) 123 45 67"
# "8-910-123-45-67"
# "8(910)123-45-67"
# "8 910 1234567"
# "89101234567"
# "+79101234567"
# ```
# 1.5 points - if the function returns a string consisting only of the digits `89101234567`, `79101234567`.
#
# 3 points - if the function also replaces the initial 8 with +7: `+79101234567`.
